# %%
# !pip install dtale

# %%
import pandas as pd
import dtale

# %%
data = pd.read_csv("misdata2.csv")

# %%
data
# Out:
#     Unnamed: 0                nombre inicial             mayuscula
# 0            0          Mr. Joe Hull       M          MR. JOE HULL
# 1            1           Mary Walker       M           MARY WALKER
# 2            2      Jennifer Vasquez       J      JENNIFER VASQUEZ
# 3            3      Nathaniel Thomas       N      NATHANIEL THOMAS
# 4            4          Joseph Davis       J          JOSEPH DAVIS
# 5            5      Richard Mckenzie       R      RICHARD MCKENZIE
# 6            6        Brittany Olsen       B        BRITTANY OLSEN
# 7            7        Natasha Walker       N        NATASHA WALKER
# 8            8      Mr. Cody Wheeler       M      MR. CODY WHEELER
# 9            9        Timothy Garcia       T        TIMOTHY GARCIA
# 10          10           Eric Torres       E           ERIC TORRES
# 11          11          Jenna Phelps       J          JENNA PHELPS
# 12          12       George Campbell       G       GEORGE CAMPBELL
# ...

# %%
# Abre una pestaña con la UI de D-Tale
d = dtale.show(data)
d.open_browser()  # opcional: fuerza la apertura automática

# %%
import pandas as pd

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,51):
    lista.append({'nombre': fake.name(), 'apellido':fake.last_name(), 'ciudad': fake.city()})

# %%
lista
# Out:
# [{'nombre': 'Kenneth Carey', 'apellido': 'Miller', 'ciudad': 'New Gailland'},
#  {'nombre': 'Angela Campbell',
#   'apellido': 'Henry',
#   'ciudad': 'South Veronicaside'},
#  {'nombre': 'Jessica Schmidt', 'apellido': 'Bradley', 'ciudad': 'North Mark'},
#  {'nombre': 'Jonathan Myers',
#   'apellido': 'Brennan',
#   'ciudad': 'Port Robertfort'},
#  {'nombre': 'Lauren Kelley', 'apellido': 'Hester', 'ciudad': 'Leemouth'},
#  {'nombre': 'Dawn David', 'apellido': 'Landry', 'ciudad': 'West Ashleyfurt'},
#  {'nombre': 'Tyler Williams', 'apellido': 'Morales', 'ciudad': 'Bellstad'},
#  {'nombre': 'Steven Reilly', 'apellido': 'Krueger', 'ciudad': 'Chandlermouth'},
#  {'nombre': 'Erica Turner', 'apellido': 'Miller', 'ciudad': 'Shahchester'},
#  {'nombre': 'Michael Clark', 'apellido': 'Pham', 'ciudad': 'Port Deanna'},
#  {'nombre': 'Curtis Page', 'apellido': 'Stout', 'ciudad': 'Carterfurt'},
#  {'nombre': 'Kristina Wright', 'apellido': 'Munoz', 'ciudad': 'Gabriellaview'},
# ...

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                 nombre    apellido                ciudad
# 0        Kenneth Carey      Miller          New Gailland
# 1      Angela Campbell       Henry    South Veronicaside
# 2      Jessica Schmidt     Bradley            North Mark
# 3       Jonathan Myers     Brennan       Port Robertfort
# 4        Lauren Kelley      Hester              Leemouth
# 5           Dawn David      Landry       West Ashleyfurt
# 6       Tyler Williams     Morales              Bellstad
# 7        Steven Reilly     Krueger         Chandlermouth
# 8         Erica Turner      Miller           Shahchester
# 9        Michael Clark        Pham           Port Deanna
# 10         Curtis Page       Stout            Carterfurt
# 11     Kristina Wright       Munoz         Gabriellaview
# 12     Samantha Powell     Herring               Fryport
# 13         Cindy Smith     Mcclure            Brentville
# 14           Mia Allen  Valenzuela           New Rebecca
# ...

# %%
data.to_csv("misdata3.csv", index=False)

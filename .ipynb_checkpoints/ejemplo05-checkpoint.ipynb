# %%
import pandas as pd

# %%
data = pd.read_json("https://raw.githubusercontent.com/PlataformasWeb-P-AA2025/clase03-1bim-reroes/refs/heads/main/ejercicio/data/data_instituciones.json")

# %%
data
# Out:
#         AMIE                                Nombre-Educativa   Provincia  \
# 0   08H02231                                 8 DE SEPTIEMBRE  ESMERALDAS
# 1   08H02177                                       ECO-MUNDO  ESMERALDAS
# 2   08H02186                           ARTESANAL MODA ACTUAL  ESMERALDAS
# 3   08H01156  CENTRO DE FORMACION ARTESANAL 21 DE SEPTIEMBRE  ESMERALDAS
# 4   08H01161                   FREDESULINDA ROSERO  DE  PÁEZ  ESMERALDAS
# ..       ...                                             ...         ...
# 94  13H03816                CENTRO DE EDUCACION LAS MERCEDES      MANABI
# 95  13H03736                                     10 DE JUNIO      MANABI
# 96  13H03768                           ANTONIO JOSE DE SUCRE      MANABI
# 97  13H04086                                  DANIEL MOREIRA      MANABI
# 98  13H04741                             ELOY ALFARO DELGADO      MANABI
#
#           Canton                Parroquia ZonaAdministrativa CodigoDistrito  \
# ...

# %%
import pygwalker as pyg

# %%
pyg.walk(data)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-000633926a085506HtsAnXpKU5caJquS" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "000633926a085506HtsAnXpKU5caJquS") {
#             var iframe = document.getElementById("gwalker-000633926a085506HtsAnXpKU5caJquS");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>

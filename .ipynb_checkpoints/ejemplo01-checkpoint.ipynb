# %%
import pandas as pd

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-37.1.0-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: tzdata in c:\users\denni\appdata\local\programs\python\python310\lib\site-packages (from faker) (2025.2)
# Installing collected packages: faker
# Successfully installed faker-37.1.0
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\DENNI\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,51):
    lista.append({'nombre': fake.name()})

# %%
lista
# Out:
# [{'nombre': 'Mr. Joe Hull'},
#  {'nombre': 'Mary Walker'},
#  {'nombre': 'Jennifer Vasquez'},
#  {'nombre': 'Nathaniel Thomas'},
#  {'nombre': 'Joseph Davis'},
#  {'nombre': 'Richard Mckenzie'},
#  {'nombre': 'Brittany Olsen'},
#  {'nombre': 'Natasha Walker'},
#  {'nombre': 'Mr. Cody Wheeler'},
#  {'nombre': 'Timothy Garcia'},
#  {'nombre': 'Eric Torres'},
#  {'nombre': 'Jenna Phelps'},
#  {'nombre': 'George Campbell'},
#  {'nombre': 'Karen Rivera'},
#  {'nombre': 'Michael Young'},
#  {'nombre': 'Debbie Lopez'},
#  {'nombre': 'Tammy Fuentes'},
#  {'nombre': 'Michael Neal'},
#  {'nombre': 'Mark Bowen'},
#  {'nombre': 'Natalie Watkins'},
#  {'nombre': 'Sarah Lane'},
#  {'nombre': 'Andrew Chavez'},
#  {'nombre': 'Shelby Bates'},
#  {'nombre': 'Andrew Lopez'},
#  {'nombre': 'Mark Rodriguez'},
#  {'nombre': 'Mary Simpson'},
#  {'nombre': 'Latoya Porter'},
#  {'nombre': 'April Stephenson'},
#  {'nombre': 'Alex Burke'},
#  {'nombre': 'Kevin Simmons'},
#  {'nombre': 'Megan Cooper'},
#  {'nombre': 'Crystal Hurley'},
#  {'nombre': 'Tammy Wells'},
#  {'nombre': 'Christina Adams'},
#  {'nombre': 'Anthony Payne'},
#  {'nombre': 'Susan Huang'},
#  {'nombre': 'Christopher Stanton'},
#  {'nombre': 'Phillip Lam'},
#  {'nombre': 'Dr. Jacqueline Duran'},
#  {'nombre': 'Justin Smith'},
#  {'nombre': 'Rebecca Hester'},
#  {'nombre': 'Collin Thompson'},
#  {'nombre': 'Katrina Reed'},
#  {'nombre': 'Charles Rios'},
#  {'nombre': 'James Patterson'},
#  {'nombre': 'Raymond Costa'},
#  {'nombre': 'Susan Miller'},
#  {'nombre': 'Lisa Hale'},
#  {'nombre': 'Robin Goodman'},
#  {'nombre': 'Stephanie Craig'},
#  {'nombre': 'Catherine Moran'}]

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                   nombre
# 0           Mr. Joe Hull
# 1            Mary Walker
# 2       Jennifer Vasquez
# 3       Nathaniel Thomas
# 4           Joseph Davis
# 5       Richard Mckenzie
# 6         Brittany Olsen
# 7         Natasha Walker
# 8       Mr. Cody Wheeler
# 9         Timothy Garcia
# 10           Eric Torres
# 11          Jenna Phelps
# 12       George Campbell
# 13          Karen Rivera
# 14         Michael Young
# 15          Debbie Lopez
# 16         Tammy Fuentes
# 17          Michael Neal
# 18            Mark Bowen
# 19       Natalie Watkins
# 20            Sarah Lane
# 21         Andrew Chavez
# 22          Shelby Bates
# 23          Andrew Lopez
# 24        Mark Rodriguez
# 25          Mary Simpson
# 26         Latoya Porter
# 27      April Stephenson
# 28            Alex Burke
# 29         Kevin Simmons
# 30          Megan Cooper
# 31        Crystal Hurley
# 32           Tammy Wells
# 33       Christina Adams
# 34         Anthony Payne
# 35           Susan Huang
# 36   Christopher Stanton
# 37           Phillip Lam
# 38  Dr. Jacqueline Duran
# 39          Justin Smith
# 40        Rebecca Hester
# 41       Collin Thompson
# 42          Katrina Reed
# 43          Charles Rios
# 44       James Patterson
# 45         Raymond Costa
# 46          Susan Miller
# 47             Lisa Hale
# 48         Robin Goodman
# 49       Stephanie Craig
# 50       Catherine Moran

# %%
data.to_csv("misdata.csv", index=False)
